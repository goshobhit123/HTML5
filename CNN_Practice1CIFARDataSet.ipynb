# %% [markdown]
# <a href="https://colab.research.google.com/github/goshobhit123/HTML5/blob/master/CNN_Practice1CIFARDataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
